# %%
import pandas

# %%
pandas.read_csv('data.csv')
# Out:
#     sample NaNtive designed  seq  expr  yield       kcat        err1  \
# 0     w34a       w        a   34     0    NaN        NaN         NaN
# 1    w120a       w        a  120     0    NaN        NaN         NaN
# 2    h315n       h        n  315     0    NaN        NaN         NaN
# 3    m323k       m        k  323     0    NaN        NaN         NaN
# 4    d403a       d        a  403     0    NaN        NaN         NaN
# 5    f405a       f        a  405     0    NaN        NaN         NaN
# 6    w407q       w        q  407     0    NaN        NaN         NaN
# 7    w409a       w        a  409     0    NaN        NaN         NaN
# 8    a357a       a        a  357     1   1.92    700.000   18.594755
# 9    i300n       i        n  300     1   1.51    700.000   12.738005
# 10   w399s       w        s  399     1   1.50        NaN         NaN
# 11   q313r       q        r  313     1   1.44    700.000   23.932799
# 12   e154d       e        d  154     1   1.42    900.000   46.700179
# ...
