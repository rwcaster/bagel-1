# %%
import pandas
dic = pandas.read_csv('looked-at.prn', delimiter=r'\s+')

# %%
dic.head()
# Out:
#   sample native designedseq expr yield          log(kcatkcat  \
# 0   r76a      r           a   76     1                  0.10
# 1  m261e      m           e  261     1  0.111.7898196.16E+01
# 2  w407a      w           a  407     1  0.131.0574041.14E+01
# 3  h379r      h           r  379     1                  0.14
# 4  e222r      e           r  222     1                  0.15
#
#                  err1/kcaerr1                     log(km)             km  \
# 0             0.415732.60E+00  6%0.159476-1.868591.35E-02  19%0.002558NA
# 1                  8%4.963316             -1.99481.01E-02  27%0.002704NA
# 2  4%0.489004-2.118757.61E-03               15%0.001153NA            NaN
# 3             0.375452.37E+00  4%0.086643-2.204816.24E-03            13%
# 4             1.626534.23E+01  4%1.873085-2.606412.48E-03  18%0.000442NA
#
#      err2/km err2 linear_sstd_err/std_err    R       ki      err6    note  \
# 0        NaN  NaN                     NaN  NaN      NaN    192.45     893
# ...
