# %%
import pandas
pandas.read_csv('out/raw-out.csv')
# Out:
#           sample  yield          kcat          err1            km  \
# 0          a192s  1.168    945.844726  9.727619e+00      0.005089
# 1          a356a  0.744    799.776836  1.174705e+01      0.006958
# 2          a357a  1.924    695.172461  1.859476e+01      0.004131
# 3          a408a  0.804   1467.941630  2.738704e+01      0.004353
# 4          c167a  0.579    478.943319  1.437735e+01      0.014565
# 5    c167n+w120r  0.244      0.359265  7.863222e-02      0.026202
# 6          c167q  0.938    503.672187  5.540034e+00      0.004918
# 7          d403a  0.120      1.190297  2.705064e-01      0.044017
# 8          e154d  1.420    878.077561  4.670018e+01      0.003457
# 9          e164a  0.420      0.216480  1.603726e-02      0.001311
# 10         e177a  0.960    986.184002  9.964381e+00      0.005984
# 11         e177k  0.953    554.938730  7.277037e+00      0.006193
# 12         e177l  0.765    669.545894  1.005508e+01      0.007483
# ...

# %%
#121 fits
pandas.read_csv('data-edited.csv')
# Out:
#       plate sample  yield  dilution well         max v        kobs        s  \
# 0         1  e406a  0.567      0.10   a1  2.070000e-04    0.330463  0.07500
# 1         1  e406a  0.567      0.10   b1  9.090000e-05    0.145365  0.01875
# 2         1  e406a  0.567      0.10   c1  4.730000e-05    0.075590  0.00469
# 3         1  e406a  0.567      0.10   d1 -2.050000e-17   -0.000000  0.00117
# 4         1  e406a  0.567      0.10   e1  8.230000e-05    0.131520  0.00029
# 5         1  e406a  0.567      0.10   f1  2.790000e-05    0.044579  0.00007
# 6         1  e406a  0.567      0.10   h1  9.090000e-06    0.014537  0.00000
# 7         1  e406a  0.567      0.10   a2  2.570000e-04    0.410898  0.07500
# 8         1  e406a  0.567      0.10   b2  7.390000e-05    0.118230  0.01875
# 9         1  e406a  0.567      0.10   c2  4.420000e-05    0.070744  0.00469
# 10        1  e406a  0.567      0.10   g2  1.050000e-05    0.016714  0.00002
# ...

# %%
# from 2965 rows 
2965/121
# Out:
# 24.50413223140496

# %%
pandas.read_csv('out/raw-out.csv')
# Out:
#           sample  yield          kcat          err1            km  \
# 0          a192s  1.168    945.844726  9.727619e+00      0.005089
# 1          a356a  0.744    799.776836  1.174705e+01      0.006958
# 2          a357a  1.924    695.172461  1.859476e+01      0.004131
# 3          a408a  0.804   1467.941630  2.738704e+01      0.004353
# 4          c167a  0.579    478.943319  1.437735e+01      0.014565
# 5    c167n+w120r  0.244      0.359265  7.863222e-02      0.026202
# 6          c167q  0.938    503.672187  5.540034e+00      0.004918
# 7          d403a  0.120      1.190297  2.705064e-01      0.044017
# 8          e154d  1.420    878.077561  4.670018e+01      0.003457
# 9          e164a  0.420      0.216480  1.603726e-02      0.001311
# 10         e177a  0.960    986.184002  9.964381e+00      0.005984
# 11         e177k  0.953    554.938730  7.277037e+00      0.006193
# 12         e177l  0.765    669.545894  1.005508e+01      0.007483
# ...

# %%
# since the linear fit will always estimate a lower kcat/km than the michaelis-menten fit, 
# let's filter out stuff with a linear slope of less than 10, our-agreed-upon LOD
df = pandas.read_csv('out/raw-out.csv')
df[(df['slope'] < 10)]
# Out:
#           sample  yield          kcat          err1            km  \
# 5    c167n+w120r  0.244      0.359265  7.863222e-02      0.026202
# 7          d403a  0.120      1.190297  2.705064e-01      0.044017
# 9          e164a  0.420      0.216480  1.603726e-02      0.001311
# 20         e406a  0.567      1.095183  8.097061e-01      0.143238
# 23          e53a  0.560  83380.426422  7.757144e+09  40164.097435
# 24         f405a  0.113      0.453617  6.656517e-02      0.002854
# 30         h119e  0.249      0.681822  1.516900e-01      0.176798
# 55   n220d+n293d  0.206      0.861088  4.818516e-02      0.034055
# 61         p329w  0.465      0.373754  1.280537e-01      0.025047
# 62          q19a  0.257      0.497987  1.487455e-01      0.074164
# 63          q19c  0.404      1.385674  3.450206e+00      0.114373
# 64          q19s  0.431      0.720767  8.452559e-02      0.057235
# 92          w34a  0.100      0.517575  2.717839e-01      0.046317
# ...

# %%
# try to keep any good MM fits 
df[(df['slope'] < 10)&(df['err1']/df['kcat'] < 0.25)&(df['err2']/df['km'] < 0.25)]
# Out:
#          sample  yield      kcat      err1        km      err2     slope  \
# 55  n220d+n293d  0.206  0.861088  0.048185  0.034055  0.004485  7.946528
# 64         q19s  0.431  0.720767  0.084526  0.057235  0.013225  5.444055
# 93        w399a  0.957  0.235170  0.012213  0.016650  0.002525  2.574192
#
#      std_err         R
# 55  0.504773  0.958368
# 64  0.277266  0.972633
# 93  0.217126  0.929873

# %%
# actually, who cares? we're done with these 
cut1 = df[(df['slope'] < 10)]

# %%
cut1.describe()
# Out:
#            yield          kcat          err1            km          err2  \
# count  22.000000     22.000000  2.200000e+01     22.000000  2.200000e+01
# mean    0.464091   3790.571505  3.525974e+08   1825.738136  1.698454e+08
# std     0.382388  17776.643329  1.653829e+09   8562.992606  7.966456e+08
# min     0.100000      0.093733  9.646938e-03      0.000007  2.220277e-05
# 25%     0.167000      0.275726  5.218559e-02      0.013875  4.551549e-03
# 50%     0.412000      0.475802  1.060527e-01      0.033810  2.176697e-02
# 75%     0.565250      0.935250  2.714645e-01      0.104321  5.226477e-02
# max     1.500000  83380.426422  7.757144e+09  40164.097435  3.736599e+09
#
#            slope    std_err          R
# count  22.000000  22.000000  22.000000
# mean    3.876626   0.599852   0.806529
# std     2.347027   0.604987   0.188516
# min     0.904007   0.077096   0.211011
# 25%     2.357633   0.234852   0.720170
# 50%     3.369752   0.472200   0.875832
# ...

# %%
# cut cut1 from df
df = df[ (df['slope'] > 10) ]
wts = df[( df['sample'].str.match('wt') )]

# %%
len(wts)
# Out:
# 13

# %%
wts.mean()
# Out:
# yield         1.014231
# kcat        717.650769
# err1         15.500019
# km            0.006831
# err2          0.000556
# slope      8590.874402
# std_err    1201.842800
# R             0.838458
# dtype: float64

# %%
wts = wts.mean().set_value('sample', 'wt')

# %%
wts = df[( df['sample'].str. )]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-90ca0f8ea2c2> in <module>()
# ----> 1 wts = df[ not ( df['sample'].str.match('wt') )]
#
# /usr/local/Cellar/python3/3.4.1/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/generic.py in __nonzero__(self)
#     690         raise ValueError("The truth value of a {0} is ambiguous. "
#     691                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 692                          .format(self.__class__.__name__))
#     693
#     694     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.tail(10)
# Out:
#     sample  yield        kcat       err1        km      err2         slope  \
# 109    wt4  1.977  916.234869  13.489225  0.006283  0.000340  11045.633110
# 110    wt5  1.262  644.540573  36.574954  0.005426  0.001166   7689.236803
# 111    wt6  1.465  915.689725  12.078311  0.004657  0.000240  11031.342622
# 112    wt7  0.912  731.524468  16.122489  0.006575  0.000528   8768.817921
# 113    wt8  1.167  810.359940   6.003328  0.004940  0.000141   9725.468998
# 114    wt9  0.468  884.267624   9.258695  0.005146  0.000206  10473.052605
# 115  y166p  0.176   26.515675   1.193986  0.002503  0.000454    292.857988
# 116   y18a  0.172  196.541782   9.331380  0.031547  0.003614   1846.603616
# 117  y294a  0.591  165.550512   1.598261  0.004977  0.000170   2113.283032
# 118  y294f  0.733  734.890556  10.708840  0.005987  0.000324   8857.723400
#
#          std_err         R
# 109  1446.942291  0.852021
# 110  1206.187944  0.805467
# 111  1677.711623  0.814095
# 112  1099.966580  0.861884
# ...
